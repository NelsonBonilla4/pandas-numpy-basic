# %% [markdown]
# # Agregar y eliminar datos con Pandas

# %%
import pandas as pd

# %%
df_books = pd.read_csv('data/bestsellers.csv', sep=",", header=0)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# ## Drop columns

# %%
# Borra la columna Year
df_books.drop('Year', axis=1).head(2) 

# Borrar de forma definitiva
# df_books.drop('Year', axis=1, inplace=True)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#          Genre
# 0  Non Fiction
# 1      Fiction

# %%
# Borra la columna Name
df_books.drop('Name', axis=1).head(2)
# Out:
#          Author  User Rating  Reviews  Price  Year        Genre
# 0      JJ Smith          4.7    17350      8  2016  Non Fiction
# 1  Stephen King          4.6     2052     22  2011      Fiction

# %% [markdown]
# ## Drop rows

# %%
# Borra la fila 1
df_books.drop(1, axis=0).head(2)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 2    18979     15  2018  Non Fiction

# %%
# Borra las filas 1, 2 y 3
df_books.drop([1, 2, 3], axis=0).head(2)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# Borra los primeros 10 registros
df_books.drop(range(10), axis=0).head(2)
# Out:
#                                                  Name            Author  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
#
#     User Rating  Reviews  Price  Year        Genre
# 10          4.6    23848      8  2017      Fiction
# 11          4.6      460      2  2010  Non Fiction

# %% [markdown]
# ## Add columns

# %%
import numpy as np
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
df_books["Nueva columna"] = np.nan
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre  Nueva columna
# 0  2016  Non Fiction            NaN
# 1  2011      Fiction            NaN

# %%
data = np.arange(0, df_books.shape[0])

# %%
df_books["Rango"] = data
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre  Nueva columna  Rango
# 0  2016  Non Fiction            NaN      0
# 1  2011      Fiction            NaN      1

# %%
new_rango = np.random.randint(1, 550, 550)

df_books["Nuevo Rango"] = new_rango
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Nueva columna  Rango  Nuevo Rango
# 0              NaN      0          251
# 1              NaN      1          290
# 2              NaN      2          151
# 3              NaN      3           23
# 4              NaN      4          509
# ..             ...    ...          ...
# 545            NaN    545          364
# 546            NaN    546          357
# 547            NaN    547          280
# 548            NaN    548          472
# 549            NaN    549           15
#
# [550 rows x 10 columns]

# %%
drop_head = df_books.iloc[:0, 7:9]

dd = df_books.drop(drop_head, axis=1).head(2)
dd
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre  Nuevo Rango
# 0  2016  Non Fiction          251
# 1  2011      Fiction          290

# %% [markdown]
# ## Add rows

# %%
df_books.append(df_books)
# Out:
# C:\Users\kenyi\AppData\Local\Temp\ipykernel_6692\1991810635.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_books.append(df_books)
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Nueva columna  Rango  Nuevo Rango
# 0              NaN      0          251
# 1              NaN      1          290
# 2              NaN      2          151
# 3              NaN      3           23
# 4              NaN      4          509
# ..             ...    ...          ...
# 545            NaN    545          364
# 546            NaN    546          357
# 547            NaN    547          280
# 548            NaN    548          472
# 549            NaN    549           15
#
# [1100 rows x 10 columns]

# %% [markdown]
# ### Reto personal
# - Borrar columnas por indice

# %%
# Seleccionamos solo las cabeceras
heads_drop = df_books.iloc[:0, 1:7:2]
print(heads_drop)
print(df_books.iloc[:0, :])

# Borramos las cabeceras sellecionadas en la variable heads_drop
df_books.drop(heads_drop, axis=1).head(2)
# Out:
# Empty DataFrame
# Columns: [Author, Reviews, Year]
# Index: []
# Empty DataFrame
# Columns: [Name, Author, User Rating, Reviews, Price, Year, Genre]
# Index: []
#                             Name  User Rating  Price        Genre
# 0  10-Day Green Smoothie Cleanse          4.7      8  Non Fiction
# 1              11/22/63: A Novel          4.6     22      Fiction
