# %% [markdown]
# # Cargando arrchivos a Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Leer CSV

# %%
df_books = pd.read_csv('data/bestsellers.csv', sep=',', header=0)

# %%
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# ### Cambiamos los Headers del DataFrame

# %%
pd.read_csv('data/bestsellers.csv', sep=',', header=0, names=['Nombre', 'Autor', 'Rating', 'Revisiones', 'Precio', 'Año', 'Genero'])
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Rating  Revisiones  Precio   Año       Genero
# 0                    JJ Smith     4.7       17350       8  2016  Non Fiction
# 1                Stephen King     4.6        2052      22  2011      Fiction
# ...

# %% [markdown]
# ## Leer Json

# %%
pd.read_json('data/hpcharacter.json')
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
# Obtenemos datos desde una url
todas = pd.read_html('https://es.wikipedia.org/wiki/Clasificaci%C3%B3n_de_Conmebol_para_la_Copa_Mundial_de_F%C3%BAtbol_de_2022')
taba_goleadores = todas[16]
taba_goleadores = taba_goleadores[:11]
pd.DataFrame(taba_goleadores)
# Out:
#                    Jugador  Selección     Goles   Min. Part.
# 0          Marcelo Martins    Bolivia        10  1312'    15
# 1                   Neymar     Brasil         8   900'    10
# 2              Luis Suárez    Uruguay         8  1043'    13
# 3         Lautaro Martínez  Argentina         7  1050'    14
# 4             Lionel Messi  Argentina         7  1094'    13
# 5          Michael Estrada    Ecuador         6   956'    16
# 6   Giorgian De Arrascaeta    Uruguay         5   520'     7
# 7           Alexis Sánchez      Chile  5[n. 2]​  1120'    14
# 8          Christian Cueva       Perú         5  1117'    17
# 9           Salomón Rondón  Venezuela         4   339'     4
# 10            Miguel Borja   Colombia         4   382'     9

# %%
# Json en Series
pd.read_json('data/hpcharacter.json', typ='series')
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %% [markdown]
# ## Reto
# - Visita Kaggle, descarga y carga algún dataset que te llame la atención. Muéstranos que has podido encontrar. 😄

# %% [markdown]
# ### Dataset obtenido en:
# - https://www.kaggle.com/datasets/heptapod/titanic?select=train_and_test2.csv

# %%
pd.read_csv('data/train_and_test2.csv', sep=',', header=0)
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...
